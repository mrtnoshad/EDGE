# %% [markdown]
# ### Load the MI data

# %%
import numpy as np
a = np.load('mi_all.npy')
print(a.shape)
# Out:
# (23, 2, 127, 4)

# %% [markdown]
# ### Print a part of the data

# %%
mi_xt_mean = np.mean(a,0)[0]
mi_ty_mean = np.mean(a,0)[1]
#mi_xt_mean = a[0,0,:,:]
#mi_ty_mean = a[0,1,:,:]
print(mi_xt_mean.shape)
print(mi_xt_mean)
print(mi_ty_mean)
# Out:
# (127, 4)
# [[13.23116692 10.40200698  8.79228442  6.56862126]
#  [13.22568313 10.44264017  8.55853815  6.29621011]
#  [13.22111405 10.37634199  8.357373    6.2646648 ]
#  [13.21752791  9.98441705  8.13785895  6.2841588 ]
#  [13.21400388  9.88951314  8.00119881  6.27977671]
#  [13.20988103  9.85165441  7.91110365  6.32219864]
#  [13.20860984  9.67805306  7.84462562  6.32785242]
#  [13.20515174  9.48082769  7.81222134  6.36547383]
#  [13.20258742  9.40197526  7.76261749  6.36236615]
#  [13.20098185  9.29126715  7.66649162  6.29231105]
#  [13.19595342  9.17725295  7.62851111  6.27319006]
#  [13.18873856  9.11068062  7.58261397  6.35364755]
#  [13.18714789  9.11938293  7.51318534  6.30359673]
#  [13.19169029  8.97973759  7.45749441  6.22273859]
#  [13.18550772  9.09984019  7.4278698   6.2179511 ]
#  [13.17946309  9.12102824  7.45846261  6.3015444 ]
#  [13.18210181  9.12405475  7.41087963  6.28502533]
#  [13.17691204  9.08699118  7.4439674   6.26082863]
#  [13.16824627  9.07438082  7.37329621  6.22059969]
#  [13.17233743  9.17160218  7.37974009  6.22794609]
#  [13.15871556  9.18268097  7.35989749  6.19105655]
#  [13.16090237  9.07431601  7.25463658  6.175523  ]
#  [13.16636582  9.06041428  7.29065613  6.20844441]
#  [13.16637196  9.06590282  7.29705686  6.19437544]
#  [13.15399277  9.09641856  7.30384974  6.19575705]
#  [13.15950403  9.07273412  7.27635464  6.16209921]
#  [13.15377736  9.03134972  7.19161287  6.06773369]
#  [13.14591481  9.03481102  7.25792258  6.16989153]
#  [13.14601763  9.09030712  7.26367252  6.22983264]
#  [13.1501028   9.05743092  7.24940942  6.15593266]
#  [13.14289087  9.02487345  7.20771993  6.06615275]
#  [13.14797507  9.0868236   7.21317412  6.08904765]
#  [13.14624346  9.05506679  7.26677094  6.13057634]
#  [13.14557227  9.0719434   7.28079814  6.13938037]
#  [13.13294371  9.16140157  7.32616813  6.15727445]
#  [13.13330689  9.19474151  7.29819815  6.19819616]
#  [13.13008743  9.12078418  7.31450723  6.20874322]
#  [13.12002194  9.1109485   7.32928714  6.15135914]
#  [13.13376745  9.09837253  7.32585961  6.14777136]
#  [13.11673956  9.10948783  7.32233345  6.16499193]
#  [13.12196695  9.09996072  7.26349553  6.09640445]
#  [13.12594175  8.99600034  7.31738183  6.09643705]
#  [13.11795195  9.00665103  7.28678101  6.1691662 ]
#  [13.11365788  8.99783703  7.29564488  6.10657768]
#  [13.10892007  9.01453045  7.30781204  6.15603584]
#  [13.09139245  8.95116953  7.24695536  6.13296742]
#  [3.31339103 3.28977547 3.27112964 3.21170385]
#  [3.31293775 3.29240108 3.27427495 3.21963395]
#  [3.31313991 3.29411454 3.27451404 3.21737762]
#  [3.31360699 3.28974028 3.2695241  3.21265967]
#  [3.31294042 3.29285341 3.27579614 3.21992441]
#  [3.31335716 3.28980342 3.27214995 3.21619059]
#  [3.31216539 3.29229977 3.2741169  3.22134594]
#  [3.31251283 3.2928586  3.27620577 3.22188107]
#  [3.31161    3.29330908 3.27715412 3.21951883]
#  [3.31145017 3.29315847 3.27651777 3.22562423]
#  [3.31122048 3.29436775 3.27791745 3.22760339]
#  [3.31185274 3.29616197 3.28023788 3.23040574]
#  [3.31127938 3.2946791  3.27958081 3.23035555]
#  [3.31183346 3.29703685 3.28022327 3.22996658]
#  [3.31153891 3.29815938 3.28333398 3.23518314]
#  [3.31127162 3.2977253  3.28346528 3.23874514]
#  [3.31097399 3.2997409  3.28623909 3.24344057]
#  [3.31032318 3.29944061 3.28765045 3.24447766]
#  [3.31096065 3.30133257 3.28880472 3.25043472]
#  [3.31089433 3.30029922 3.28862049 3.25116655]
#  [3.30967216 3.30087594 3.28922223 3.24993428]
#  [3.30980623 3.30103843 3.29043427 3.25520906]
#  [3.30892429 3.30275283 3.29231279 3.25813266]
#  [3.30766459 3.30213162 3.29159302 3.25447121]
#  [3.30747654 3.30155279 3.2915232  3.2573397 ]
#  [3.30677835 3.30414827 3.29529467 3.26285681]
#  [3.30654518 3.30356105 3.29573378 3.2643197 ]
#  [3.30654044 3.3037755  3.29545918 3.26572522]
#  [3.30325828 3.30367408 3.29538935 3.26590728]
#  [3.30282193 3.30287334 3.29502575 3.26480072]
#  [3.3003374  3.30519551 3.29813025 3.26913928]
#  [3.30100984 3.30576861 3.29949969 3.27329685]
#  [3.30098625 3.30560585 3.29872479 3.27301392]
#  [3.29989629 3.30562535 3.29883748 3.27378106]
#  [3.29999373 3.3051575  3.2978488  3.27300465]
#  [3.30077158 3.30561679 3.29911759 3.2742628 ]
#  [3.29806824 3.30671773 3.30034984 3.27609979]
#  [3.29935747 3.30735312 3.3014498  3.28148132]
#  [3.29886493 3.30688889 3.30100345 3.28003118]
#  [3.29577231 3.30769657 3.30224695 3.27889477]
#  [3.29586399 3.30741705 3.30177063 3.27997717]
#  [3.29696795 3.3070974  3.30147815 3.2786154 ]
#  [3.29431025 3.30799746 3.30246374 3.28096772]]

# %% [markdown]
# ### Sample from the MI data

# %%
IXM_N = mi_xt_mean[0,:]
IYM_N = mi_ty_mean[0,:]

T =1

for i in range(1,mi_xt_mean.shape[0]):
    
    A_ = i <= 4 and i % 1 == 0  
    A0 = i > 4 and i <= 10 and i % 2 == 0    
    A1 = i > 10 and i <= 30 and i % 3 == 0     
    A2 = i > 30 and i % 3 == 0    

    #if A0 or A1 or A2:
    if  A0 or A1 or A2:
        mean_vec_xt = np.mean(mi_xt_mean[T:i+1,:],axis=0)
        mean_vec_yt = np.mean(mi_ty_mean[T:i+1,:],axis=0)  
                             
        #print(T,i+1)                      
        IXM_N = np.append(IXM_N,mean_vec_xt)
        IYM_N = np.append(IYM_N,mean_vec_yt)
        
        T = i+1

        
IXM_N = np.reshape(IXM_N,(-1,4))
IYM_N = np.reshape(IYM_N,(-1,4))
print(IXM_N.shape)
# Out:
# (43, 4)

# %% [markdown]
# ### Data shape

# %%
#mi_ty_mean[0:10,3]=np.array(mi_ty_mean[0:10,3])
IXM_N, IYM_N = mi_ty_mean, mi_ty_mean
print(IXM_N.shape)
print(IYM_N.shape)
# Out:
# (127, 4)
# (127, 4)

# %% [markdown]
# ### Apply roling mean

# %%
import pandas as pd
T=3
IXM_N, IYM_N = np.zeros((mi_xt_mean.shape[0]-T+1,4)), np.zeros((mi_ty_mean.shape[0]-T+1,4))

for i in range(4):
    IXM_N[:,i]=pd.rolling_mean(mi_xt_mean[:,i],T)[T-1:]
    IYM_N[:,i]=pd.rolling_mean(mi_ty_mean[:,i],T)[T-1:]
    
print(IXM_N.shape)
print(IYM_N.shape)
# Out:
# (17, 4)
# (17, 4)
# /Users/morteza/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#
# /Users/morteza/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#   import sys

# %% [markdown]
# ### Plot Information Plane

# %%
#%matplotlib inline
import matplotlib
matplotlib.use('TkAgg')

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')


plt.figure(figsize=(8,8))
gs = gridspec.GridSpec(4,2)
#for actndx, (activation, vals) in enumerate(measures.items()):
#    epochs = sorted(vals.keys())
#    if not len(epochs):
#        continue

COLORBAR_MAX_EPOCHS=15000

plt.tight_layout()        

fig=plt.figure(figsize=(10,5))

#max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

#fig=plt.figure(figsize=(10,5))
#for actndx, (activation, vals) in enumerate(measures.items()):
#    epochs = sorted(vals.keys())
#    if not len(epochs):
#        continue
#    plt.subplot(1,2,actndx+1)    
    
    
#n_epoch = mi_xt_mean.shape[0]
n_epoch = IXM_N.shape[0]

PLOT_LAYERS = [0]
for epoch in range(0,n_epoch):
    c = sm.to_rgba(220*(epoch))
    #xmvals = np.array(vals[epoch]['MI_XM'])[PLOT_LAYERS]
    #ymvals = np.array(vals[epoch]['MI_YM'])[PLOT_LAYERS]

    #xmvals = mi_xt_mean[epoch] 
    #ymvals = mi_ty_mean[epoch]
    xmvals = IXM_N[epoch] 
    ymvals = IYM_N[epoch]
    
    plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
    plt.scatter(xmvals, ymvals, s=40, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)
    
plt.ylim([1, 3.5])
plt.xlim([4, 14])
plt.xlabel('I(X;M)')
plt.ylabel('I(Y;M)')
plt.title('Tanh')
    
# colorbar
  
#cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
#plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.colorbar(sm, label='Epoch')


plt.tight_layout()

plt.show()
